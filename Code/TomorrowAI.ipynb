# %%
import requests
API_KEY = 'owTRhynXpGxnmhQ5p56MyPQ0oMvBnvRX'

r = requests.get(f'https://api.tomorrow.io/v4/weather/forecast?location=42.3478,-71.0466&apikey={API_KEY}')
r.json()
# Out:
# {'timelines': {'minutely': [{'time': '2024-12-03T23:02:00Z',
#     'values': {'cloudBase': None,
#      'cloudCeiling': None,
#      'cloudCover': 9,
#      'dewPoint': -10,
#      'freezingRainIntensity': 0,
#      'humidity': 50,
#      'precipitationProbability': 0,
#      'pressureSurfaceLevel': 1021.05,
#      'rainIntensity': 0,
#      'sleetIntensity': 0,
#      'snowIntensity': 0,
#      'temperature': -0.81,
#      'temperatureApparent': -3.8,
#      'uvHealthConcern': 0,
#      'uvIndex': 0,
#      'visibility': 16,
#      'weatherCode': 1000,
#      'windDirection': 307,
#      'windGust': 4.63,
#      'windSpeed': 2.31}},
#    {'time': '2024-12-03T23:03:00Z',
#     'values': {'cloudBase': None,
#      'cloudCeiling': None,
#      'cloudCover': 10.57,
#      'dewPoint': -9.98,
#      'freezingRainIntensity': 0,
#      'humidity': 50.15,
#      'precipitationProbability': 0,
#      'pressureSurfaceLevel': 1021.02,
#      'rainIntensity': 0,
#      'sleetIntensity': 0,
# ...
